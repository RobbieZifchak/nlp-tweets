# %%
# !pip install spaCy
# Out:
# ...
#      |████████████████████████████████| 10.5MB 2.1MB/s eta 0:00:01    |███████████████▌                | 5.1MB 936kB/s eta 0:00:06
# ...
#      |████████████████████████████████| 2.2MB 988kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 61kB 9.3MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 4.0MB 2.7MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 215kB 2.6MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 184kB 9.9MB/s eta 0:00:01
# ...

# %%
import pandas as pd
import spacy

# %%
df = pd.read_csv('clean_anxiety_tweets.csv')

# %%
df.head()
# Out:
#                                                 text
# 0  ['okay', 'totally', 'understand', 'specific', ...
# 1  ['thing', 'know', 'returning', 'hair', 'salon'...
# 2  ['well', 'information', 'would', 'useful', 'mo...
# 3                  ['anxiety', 'greatest', 'lately']
# 4  ['mostly', 'afraid', 'really', 'anxiety', 'mis...

# %%
for items in df['text']:
    for words in items:
        print(items)
# Out:
# ['okay', 'totally', 'understand', 'specific', 'struggle', 'queer', 'japanese', 'japanese', 'people', 'open', 'learning', 'feel', 'personally', 'mean', 'exist', 'applies', 'racism', 'phobia', 'anxiety', 'list', 'go']
# ['okay', 'totally', 'understand', 'specific', 'struggle', 'queer', 'japanese', 'japanese', 'people', 'open', 'learning', 'feel', 'personally', 'mean', 'exist', 'applies', 'racism', 'phobia', 'anxiety', 'list', 'go']
# ['okay', 'totally', 'understand', 'specific', 'struggle', 'queer', 'japanese', 'japanese', 'people', 'open', 'learning', 'feel', 'personally', 'mean', 'exist', 'applies', 'racism', 'phobia', 'anxiety', 'list', 'go']
# ['okay', 'totally', 'understand', 'specific', 'struggle', 'queer', 'japanese', 'japanese', 'people', 'open', 'learning', 'feel', 'personally', 'mean', 'exist', 'applies', 'racism', 'phobia', 'anxiety', 'list', 'go']
# ...
